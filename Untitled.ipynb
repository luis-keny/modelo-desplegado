# %%
import statsmodels.api as sm
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
import joblib

# Cargar dataset
df = sm.datasets.get_rdataset("Pima.tr", "MASS").data

df
# Out:
#      npreg  glu  bp  skin   bmi    ped  age type
# 0        5   86  68    28  30.2  0.364   24   No
# 1        7  195  70    33  25.1  0.163   55  Yes
# 2        5   77  82    41  35.8  0.156   35   No
# 3        0  165  76    43  47.9  0.259   26   No
# 4        0  107  60    25  26.4  0.133   23   No
# ..     ...  ...  ..   ...   ...    ...  ...  ...
# 195      2  141  58    34  25.4  0.699   24   No
# 196      7  129  68    49  38.5  0.439   43  Yes
# 197      0  106  70    37  39.4  0.605   22   No
# 198      1  118  58    36  33.3  0.261   23   No
# 199      8  155  62    26  34.0  0.543   46  Yes
#
# [200 rows x 8 columns]

# %%
from pathlib import Path

# Codificar variable objetivo
df['type'] = LabelEncoder().fit_transform(df['type'])  # Yes=1, No=0

# Separar X e y
X = df.drop('type', axis=1)
y = df['type']

# Entrenar modelo
modelo = LogisticRegression(max_iter=1000)
modelo.fit(X, y)

# --- Guardar en carpeta artefacto/ ---
ART_DIR = Path("artefacto")
ART_DIR.mkdir(parents=True, exist_ok=True)

MODEL_PATH = ART_DIR / "modelo_pima.pkl"
joblib.dump(modelo, MODEL_PATH)
print(f"✅ Modelo guardado en {MODEL_PATH.resolve()}")

# (Opcional) Ver qué hay en artefacto/
print("Contenido de artefacto/:", list(ART_DIR.iterdir()))
# Out:
# ✅ Modelo guardado en /opt/notebooks/252ml/vide/artefacto/modelo_pima.pkl
# Contenido de artefacto/: [PosixPath('artefacto/modelo_pima.pkl')]

# %%
import os
import streamlit as st
from pathlib import Path

# Ruta a la carpeta artefacto/
carpeta = Path("artefacto")
carpeta.mkdir(exist_ok=True)

# Cambiar directorio de trabajo
os.chdir(carpeta)

# Mostrar contenido de la carpeta artefacto
st.write(os.listdir())

# Mostrar ruta actual
print(os.getcwd())
# Out:
# /opt/notebooks/252ml/vide/artefacto/artefacto/artefacto
